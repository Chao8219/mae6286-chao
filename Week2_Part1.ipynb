# %%
# %run phugoid.py
# %matplotlib inline

# %% [markdown]
# zt = 64.0, z0 = 16.0, theta0 = 0.0

# %%
zt = 64.0
z0 = 16.0
theta00 = 0.0

# %%
plot_flight_path(zt, z0, theta00)

# %% [markdown]
# zt = 64.0, z0 = 16.0, theta01 = 180.0

# %%
theta01 = 180.0

# %%
plot_flight_path(zt, z0, theta01)

# %%
plot_flight_path(16.0, 48.0, 0.0)
